# %% [markdown]
# # Exercício 1

# %%
#Alínea 1
import numpy as np
import pylab as pl
import math as mt
import matplotlib as mpl
r=np.loadtxt("sunspots.txt")
pl.plot(r[:,0],r[:,1])
pl.ylabel("Nº de Manchas Solares")
pl.xlabel("Mês")
pl.show()

# %%
#Alínea 2
d=np.loadtxt("sunspots.txt")
pl.plot(d[0:1000,0],d[0:1000,1])
pl.ylabel("Nº de Manchas Solares")
pl.xlabel("Mês")
pl.show()

# %%
#Alínear 3 sem sum function
d=np.array(list(np.loadtxt("sunspots.txt")),float)
l=list(d[0:5,1])
r=5
row,col=np.shape(d)
# descobrir número de pontos: print(np.shape(d))
for i in range(5,row-5):
    soma=0
    for j in range(i-5,i+6):
        soma+=d[j,1]
    l.append(soma/(2*r+1))
for i in range(row-5,row):
    l.append(d[i,1])


pl.plot(d[0:1000,0],d[0:1000,1])
pl.plot(d[0:1000,0],l[0:1000])
pl.ylabel("Nº de Manchas Solares / Média móvel")
pl.xlabel("Mês")
pl.show()

# %%
#Alínear 3 com sum function
d=np.array(list(np.loadtxt("sunspots.txt")),float)
l=list(d[0:5,1])
r=5
row,col=np.shape(d)
# descobrir número de pontos: print(np.shape(d))
for i in range(5,row-5):
    l.append(np.sum(d[i-5:i+6,1])/(2*r+1))
for i in range(row-5,row):
    l.append(d[i,1])


pl.plot(d[0:1000,0],d[0:1000,1])
pl.plot(d[0:1000,0],l[0:1000])
pl.ylabel("Nº de Manchas Solares / Média móvel")
pl.xlabel("Mês")
pl.show()

# %%
# Versão professor mais eficaz, numpy

t=d[0:1000,0]
y=d[0:1000,1]
r=11
z=np.zeros(len(y)-(r-1))
for i in range(r):
    z+=1/r*y[i:len(y)-(r-1)+i]
pl.plot(t,y)
pl.plot(t[int((r-1)/2):1000-int((r-1)/2)],z)
pl.ylabel("Nº de Manchas Solares / Média móvel")
pl.xlabel("Mês")
pl.show()

# %% [markdown]
# # Exercício 2

# %%
#Alínea a
teta=np.arange(0,2*mt.pi,0.001)
print(len(teta))
x=2*np.cos(teta)+np.cos(2*teta)
y=2*np.sin(teta)-np.sin(2*teta)
pl.plot(x,y)
pl.xlabel("x")
pl.ylabel("y")
pl.xlim(-2,3.5)
pl.grid()
pl.show()
# Out:
# 6284

# %%
teta1=np.arange(0,10*mt.pi,0.01)
r1=teta1**2
x1=r1*np.cos(teta1)
y1=r1*np.sin(teta1)
pl.plot(x1,y1)
pl.xlabel("x1")
pl.ylabel("y1")
pl.grid()
pl.show()

# %%
#Alínea c
teta2=np.arange(0,24*mt.pi,0.01)
r2=np.exp(np.cos(teta2))-2*np.cos(4*teta2)+np.sin(teta2/12)**5
x2=r2*np.cos(teta2)
y2=r2*np.sin(teta2)
pl.plot(x2,y2)
pl.xlabel("x2")
pl.ylabel("y2")
pl.grid()
pl.show()

# %% [markdown]
# # Exercício 3

# %%
data=np.loadtxt("stm.txt",float)
pl.imshow(data, origin="lower")
pl.gray()
pl.colorbar()
pl.show()

# %%
#Alternativa
#pl.pcolormesh(data, shading='auto' , cmap="jet")
#usar np.meshgrid(x)

# %% [markdown]
# # Á Parte

# %%
# %matplotlib notebook
fig = pl.figure()
ax = fig.add_subplot(111, projection='3d')
x,y=np.mgrid[-10:10:100j,-10:10:100j]
z=x**2+y**2
print(x)
print()
print(y)
print()
print(z)
ax.scatter(x, y, z)
ax.set_zlim(0,100)
ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [[-10.        -10.        -10.        ... -10.        -10.
#   -10.       ]
#  [ -9.7979798  -9.7979798  -9.7979798 ...  -9.7979798  -9.7979798
#    -9.7979798]
#  [ -9.5959596  -9.5959596  -9.5959596 ...  -9.5959596  -9.5959596
#    -9.5959596]
#  ...
#  [  9.5959596   9.5959596   9.5959596 ...   9.5959596   9.5959596
#     9.5959596]
#  [  9.7979798   9.7979798   9.7979798 ...   9.7979798   9.7979798
#     9.7979798]
#  [ 10.         10.         10.        ...  10.         10.
#    10.       ]]
#
# [[-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  ...
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
# ...

# %% [markdown]
# # Exercício 4

# %%
#alínea a
import vpython as vp
R=0.2
L=5
# procurar sobre canvas() pra nao ser preciso reiniciar o kernel
for i in range(-L,L+1):
    for j in range(-L, L+1):
        for k in range(-L,L+1):
            if (i+j+k)%2==0:
                vp.sphere(radius=R,pos=vp.vector(i,j,k),color=vp.color.blue)
            else:
                vp.sphere(radius=R,pos=vp.vector(i,j,k),color=vp.color.green)

# %%
#um cubo CFC
import vpython as vp
R=0.2
L=5
for i in range(0,2):
    for j in range(0, 2):
        for k in range(0,2):
            if i+j+k>=2:
                vp.sphere(radius=R,pos=vp.vector(i,j,k), color=vp.color.blue)
            elif i==1:
                vp.sphere(radius=R,pos=vp.vector(i,j,k), color=vp.color.blue)
                vp.sphere(radius=R,pos=vp.vector(i,j+0.5,k+0.5))
            elif j==1:
                vp.sphere(radius=R,pos=vp.vector(i,j,k), color=vp.color.blue)
                vp.sphere(radius=R,pos=vp.vector(i+0.5,j,k+0.5))
            elif k==1:
                vp.sphere(radius=R,pos=vp.vector(i,j,k), color=vp.color.blue)
                vp.sphere(radius=R,pos=vp.vector(i+0.5,j+0.5,k))
            else:
                vp.sphere(radius=R,pos=vp.vector(i,j,k), color=vp.color.blue)
                vp.sphere(radius=R,pos=vp.vector(i,j+0.5,k+0.5))
                vp.sphere(radius=R,pos=vp.vector(i+0.5,j+0.5,k))
                vp.sphere(radius=R,pos=vp.vector(i+0.5,j,k+0.5))

# %%
import vpython as vp
R=0.2
L=5
for k in range(-L,L+1):
    for j in range(-L,L+1):
        for i in range(-L,L+1):
            vp.sphere(radius=R,pos=vp.vector(i,j,k), color=vp.color.blue)
            if j<L and i<L:
                vp.sphere(radius=R,pos=vp.vector(i+0.5,j+0.5,k))
            if k<L:
                if i<L:
                    vp.sphere(radius=R,pos=vp.vector(i+0.5,j,k+0.5))
                if j<L:
                    vp.sphere(radius=R,pos=vp.vector(i,j+0.5,k+0.5))
#for k in range(-L,L):
#    for j in range(-L,L+1):
#        for i in range(-L,L+1):
#           if i<L:
#                vp.sphere(radius=R,pos=vp.vector(i+0.5,j,k+0.5))
#            if j<L:
#                vp.sphere(radius=R,pos=vp.vector(i,j+0.5,k+0.5))

# %% [markdown]
# # Exercício 5

# %%
import vpython as vp
import math as mt
import numpy as np

#Parâmetros
c1=2500
cs=750
c2=0.5

#Dados planetas
data=np.array([[2440,57.9e6,88.0],
               [6052,108.2e6,224.7],
               [6371,149.6e6,365.3],
               [3386,227.9e6,687.0],
               [69173,778.5e6,4331.6],
               [57316,1433.4e6,10759.2]],float)
cores=[vp.color.white,vp.color.orange,vp.color.blue,vp.color.magenta,vp.color.gray(0.5),vp.color.yellow]
data[:,0]*=c1
#Frequência Angular
data[:,2]=(2*mt.pi)/data[:,2]

#Representar planetas
sol=vp.sphere(radius=695500*cs,pos=vp.vector(0,0,0),color=vp.color.yellow)
planetas=np.empty(len(data),vp.sphere)
for i in range(len(data)):
    planetas[i]=vp.sphere(radius=data[i,0],pos=vp.vector(data[i,1]+695500*cs,0,0),color=cores[i])
    
#Animação
t=0
while True:
    vp.rate(30)
    for j in range(len(planetas)):
        planetas[j].pos=vp.vector((data[j,1]+695500*cs)*mt.cos(data[j,2]*t),(data[j,1]+695500*cs)*mt.sin(data[j,2]*t),0)
    t+=1*c2

# %% [markdown]
# # Exercício 6

# %%
import math as mt
import numpy as np
import pylab as pl
x0=1/2
r=1
def mapa_xvsx_(x0,r):
    x=[]
    x_=[]
    i=0
    while i!=1000:
        x.append(x0)
        x0=r*x0*(1-x0)
        x_.append(x0)
        i+=1
    pl.scatter(x,x_, s=10, color="black")
    pl.xlim(0,0.60)
    pl.ylim(0,0.30)
    pl.xlabel("x", size=20, color="blue")
    pl.ylabel("x'", size=20, color="blue")
    pl.grid()
    pl.show()

mapa_xvsx_(x0,r)

# %%
def mapa_rvsx(x0,r):
    x_=[]
    i=0
    while i!=1000:
        x0=r*x0*(1-x0)
        x_.append(x0)
        i+=1
    r_=np.ones(len(x_))*r
    pl.scatter(r_,x_,s=1,color="black")

for r in np.arange(1,4,0.01):
    mapa_rvsx(0.5,r)
    
pl.xlabel("r", size=20, color="blue")
pl.ylabel("x", size=20, color="blue")
pl.grid()
pl.show()

# %%
#Não sei qual o gráfico que é suposto aparecer (o de cima ou o de baixo)
#Mais Eficaz
r=np.arange(1,4,0.0001)
x=np.ones(len(r))*0.5
i=0
while i!=1000:
    x=r*x*(1-x)    
    i+=1
pl.scatter(r,x,s=1,color="black")
pl.xlabel("r", size=20, color="blue")
pl.ylabel("x", size=20, color="blue")
pl.grid()
pl.show()

# %% [markdown]
# # Exercício 7

# %%
def Mandelbrot(c,n=100):
    z=0+0j
    z_mod=0
    i=0
    while i != n and z_mod<=2:
        z=z**2+c
        z_mod=(z.real**2+z.imag**2)**0.5
        i+=1
    return i==n

# %%
N=1000
grelha=np.empty([N,N],float)
espaçamento=4/N
for i in range(N):
    x=-2+espaçamento*i
    for k in range(N):
        y=-2+espaçamento*k
        grelha[i,k]=Mandelbrot(complex(x,y))
pl.imshow(grelha, origin="lower", extent=[-2,2,-2,2])
pl.gray()
pl.colorbar()
pl.xlabel("Parte Real", size=15)
pl.ylabel("Parte Imaginária", size=15)
# Out:
# Text(0, 0.5, 'Parte Imaginária')

# %%
def Mandelbrot2(c,n=100):
    z=0+0j
    z_mod=0
    i=0
    while i != n and z_mod<=2:
        z=z**2+c
        z_mod=(z.real**2+z.imag**2)**0.5
        i+=1
    return i

N=1000
grelha=np.empty([N,N],float)
espaçamento=4/N
for i in range(N):
    x=-2+espaçamento*i
    for k in range(N):
        y=-2+espaçamento*k
        grelha[i,k]=Mandelbrot2(complex(x,y))
pl.imshow(grelha, origin="lower", extent=[-2,2,-2,2])
pl.viridis()
pl.colorbar()
pl.xlabel("Parte Real")
pl.ylabel("Parte Imaginária")
pl.clim(0,100)

# %%
#Versão mais rápida
x,y=np.mgrid[-2:2:1000j,-2:2:1000j]
c=x+y*1j
z=0+0j
for i in range(100):
    z=z**2+c
z_mod=(z.real**2+z.imag**2)**0.5
pl.imshow(z_mod<2, origin="lower", extent=[-2,2,-2,2])
pl.gray()
pl.colorbar()
pl.xlabel("Parte Real", size=15)
pl.ylabel("Parte Imaginária", size=15)
# Out:
# <ipython-input-67-d5ad3acf1eb1>:6: RuntimeWarning: overflow encountered in square
#   z=z**2+c
# <ipython-input-67-d5ad3acf1eb1>:6: RuntimeWarning: invalid value encountered in square
#   z=z**2+c
# <ipython-input-67-d5ad3acf1eb1>:7: RuntimeWarning: overflow encountered in square
#   z_mod=(z.real**2+z.imag**2)**0.5
# Text(0, 0.5, 'Parte Imaginária')

# %%
#Menos eficaz xxxxxxx
def Mandelbrot2(c,n=100):
    z=0+0j
    z_mod=0
    i=0
    while i != n and z_mod<=2:
        z=z**2+c
        z_mod=(z.real**2+z.imag**2)**0.5
        i+=1
    return i

x,y=np.mgrid[-2:2:1000j,-2:2:1000j]
dados=np.empty([1000,1000],int)
c=x+y*1j
for i in range(1000):
    for k in range(1000):
        dados[i,k]=Mandelbrot2(c[i,k])
pl.imshow(dados, origin="lower", extent=[-2,2,-2,2])
pl.viridis()
pl.colorbar()
pl.xlabel("Parte Real")
pl.ylabel("Parte Imaginária")
pl.clim(0,100)
